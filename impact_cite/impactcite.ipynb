# %%
# !pip install transformers==4.19.4
# !pip install datasets==2.13.1
# !pip install evaluate==0.4.0
# !pip install rouge-score==0.1.2
# !pip install py7zr
# Out:
# Requirement already satisfied: transformers==4.19.4 in /usr/local/lib/python3.10/dist-packages (4.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (0.12.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.4) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.19.4) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.19.4) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.19.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.19.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.19.4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.19.4) (2023.11.17)
# Requirement already satisfied: datasets==2.13.1 in /usr/local/lib/python3.10/dist-packages (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (10.0.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (3.9.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.13.1) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.13.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.13.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.13.1) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.13.1) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.13.1) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.13.1) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets==2.13.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets==2.13.1) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.13.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.13.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.13.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.13.1) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.13.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.13.1) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets==2.13.1) (1.16.0)
# Requirement already satisfied: evaluate==0.4.0 in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (1.23.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (23.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate==0.4.0) (10.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate==0.4.0) (3.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate==0.4.0) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate==0.4.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate==0.4.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate==0.4.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate==0.4.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate==0.4.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate==0.4.0) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate==0.4.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate==0.4.0) (2023.3.post1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate==0.4.0) (1.16.0)
# Requirement already satisfied: rouge-score==0.1.2 in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2) (1.23.5)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score==0.1.2) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score==0.1.2) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score==0.1.2) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score==0.1.2) (4.66.1)
# Requirement already satisfied: py7zr in /usr/local/lib/python3.10/dist-packages (0.20.8)
# Requirement already satisfied: texttable in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /usr/local/lib/python3.10/dist-packages (from py7zr) (3.19.1)
# Requirement already satisfied: pyzstd>=0.15.9 in /usr/local/lib/python3.10/dist-packages (from py7zr) (0.15.9)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from py7zr) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from py7zr) (1.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from py7zr) (5.9.5)

# %%
import os
import random
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from datasets import DatasetDict, Dataset, load_dataset, concatenate_datasets

from transformers import (
    Trainer,
    TrainingArguments,
    AutoTokenizer,
    AutoModelForSequenceClassification,
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
os.environ['TOKENIZERS_PARALLELISM'] = 'false' # there might be interferences with the parallelism of the Hugging Face Trainer

# %%
# model = AutoModelForSequenceClassification.from_pretrained("xlnet-base-cased", num_labels=2)
tokenizer = AutoTokenizer.from_pretrained("xlnet-base-cased")

# %%
folds_dict = {}

for i in range(10):
    df_name = f'fold_{i+1}'
    df = pd.read_csv(f'/content/drive/MyDrive/citation_sentiment_data/folds/{df_name}.csv')
    folds_dict[df_name] = df

for f in folds_dict:
  folds_dict[f] = Dataset.from_pandas(folds_dict[f])

dataset = DatasetDict(folds_dict)

def tokenize_seqs(examples):
    return tokenizer(examples['citation'], padding = True, truncation=True, max_length=512, return_tensors="pt")

tokenized_data = dataset.map(tokenize_seqs, batched=True)
# Out:
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]
# Map:   0%|          | 0/798 [00:00<?, ? examples/s]

# %% [markdown]
# Labels: <br>
# > O - neutral <br>
# > 1 - opinionated<br>
# <br>

# %%
tokenized_data = tokenized_data.rename_column('label', 'labels')

# %%
def compute_metrics(eval_preds):
    y_true = eval_preds.label_ids
    y_pred = eval_preds.predictions.argmax(axis=1)
    f1 = f1_score(y_true, y_pred, average='weighted')
    return {'f1': f1}

# %%
# creating a list of all folds
fold_list = [tokenized_data[f'fold_{i+1}'] for i in range(10)]

# %%
# selecting one fold as eval set based on its index
eval_data = fold_list[0]

# %%
train_folds = fold_list.copy()
del train_folds[0]
train_data = concatenate_datasets(train_folds)

# %%
per_device_train_batch_size = 4

# %%
training_args = TrainingArguments(
    output_dir ='./logs/fold1',
    per_device_train_batch_size = per_device_train_batch_size,
    per_device_eval_batch_size  = per_device_train_batch_size*4,
    learning_rate = 2e-5,
    weight_decay = 1e-3,
    num_train_epochs = 3,
    evaluation_strategy = 'epoch',
    logging_strategy = 'steps',
    logging_steps = len(train_data) / per_device_train_batch_size,
    save_strategy = 'epoch',
    save_total_limit = 1,
    seed = 42,
    data_seed = 42,
    fp16 = True,
    dataloader_num_workers = 2,
    load_best_model_at_end = True
)

# %%
trainer = Trainer(model=model, args=training_args, compute_metrics = compute_metrics, train_dataset = train_data, eval_dataset = eval_data, tokenizer = tokenizer)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: citation. If citation are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 7182
#   Num Epochs = 3
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 5388
#     <div>
#
#       <progress value='5388' max='5388' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5388/5388 17:01, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.396571</td>
#       <td>0.890061</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.430900</td>
#       <td>0.371940</td>
#       <td>0.916939</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.430900</td>
#       <td>0.373322</td>
#       <td>0.917722</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: citation. If citation are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 798
#   Batch size = 16
# Saving model checkpoint to ./logs/fold1/checkpoint-1796
# Configuration saved in ./logs/fold1/checkpoint-1796/config.json
# Model weights saved in ./logs/fold1/checkpoint-1796/pytorch_model.bin
# tokenizer config file saved in ./logs/fold1/checkpoint-1796/tokenizer_config.json
# Special tokens file saved in ./logs/fold1/checkpoint-1796/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: citation. If citation are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 798
#   Batch size = 16
# Saving model checkpoint to ./logs/fold1/checkpoint-3592
# Configuration saved in ./logs/fold1/checkpoint-3592/config.json
# Model weights saved in ./logs/fold1/checkpoint-3592/pytorch_model.bin
# tokenizer config file saved in ./logs/fold1/checkpoint-3592/tokenizer_config.json
# Special tokens file saved in ./logs/fold1/checkpoint-3592/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: citation. If citation are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 798
#   Batch size = 16
# Saving model checkpoint to ./logs/fold1/checkpoint-5388
# Configuration saved in ./logs/fold1/checkpoint-5388/config.json
# Model weights saved in ./logs/fold1/checkpoint-5388/pytorch_model.bin
# tokenizer config file saved in ./logs/fold1/checkpoint-5388/tokenizer_config.json
# Special tokens file saved in ./logs/fold1/checkpoint-5388/special_tokens_map.json
# Deleting older checkpoint [logs/fold1/checkpoint-1796] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./logs/fold1/checkpoint-3592 (score: 0.371940016746521).
# TrainOutput(global_step=5388, training_loss=0.37478910699630547, metrics={'train_runtime': 1024.3523, 'train_samples_per_second': 21.034, 'train_steps_per_second': 5.26, 'total_flos': 6138030503227392.0, 'train_loss': 0.37478910699630547, 'epoch': 3.0})

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from huggingface_hub import create_repo
create_repo("Velkymoss/impact-cite", private=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     269     try:
# --> 270         response.raise_for_status()
#     271     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 409 Client Error: Conflict for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-9-5f386965a878> in <cell line: 2>()
#       1 from huggingface_hub import create_repo
# ----> 2 create_repo("Velkymoss/impact-cite", private=True)
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in create_repo(self, repo_id, token, private, repo_type, exist_ok, space_sdk, space_hardware, space_storage, space_sleep_time, space_secrets, space_variables)
#    2814
#    2815         try:
# -> 2816             hf_raise_for_status(r)
#    2817         except HTTPError as err:
#    2818             if exist_ok and err.response.status_code == 409:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     328         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     329         # as well (request id and/or server error message)
# --> 330         raise HfHubHTTPError(str(e), response=response) from e
#     331
#     332
#
# HfHubHTTPError: 409 Client Error: Conflict for url: https://huggingface.co/api/repos/create (Request ID: Root=1-658f1bd4-070137ab1bc21951400225fd;7f876d2b-9778-47c3-bcd9-4f2118af31e1)
#
# You already created this model repo

# %%
# !mkdir model_f1
model.save_pretrained('model_f1')

# %%
model.push_to_hub('impact-cite')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:127: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Configuration saved in impact-cite/config.json
# Model weights saved in impact-cite/pytorch_model.bin
# Upload file pytorch_model.bin:   0%|          | 1.00/448M [00:00<?, ?B/s]
# To https://huggingface.co/Velkymoss/impact-cite
#    52ccae8..af0790e  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/Velkymoss/impact-cite
#    52ccae8..af0790e  main -> main
# 'https://huggingface.co/Velkymoss/impact-cite/commit/af0790e16b670891611ae38327eaa1b4f3b5bf94'
